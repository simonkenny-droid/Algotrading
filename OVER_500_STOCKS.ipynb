# %%
import yfinance as yf
import pandas as pd
import numpy as np
import ta
import matplotlib.pyplot as plt

# %%
pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1                     Building Products     Milwaukee, Wisconsin  2017-07-26
# 2                 Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                       Pharmaceuticals  North Chicago, Illinois  2012-12-31
# 4        IT Consulting & Other Services          Dublin, Ireland  2011-07-06
# ..                                  ...                      ...         ...
# 498                         Restaurants     Louisville, Kentucky  1997-10-06
# 499  Electronic Equipment & Instruments   Lincolnshire, Illinois  2019-12-23
# 500               Health Care Equipment          Warsaw, Indiana  2001-08-07
# 501                      Regional Banks     Salt Lake City, Utah  2001-06-22
# 502                     Pharmaceuticals   Parsippany, New Jersey  2013-06-21
#
#          CIK      Founded
# 0      66740         1902
# 1      91142         1916
# 2       1800         1888
# 3    1551152  2013 (1888)
# 4    1467373         1989
# ..       ...          ...
# 498  1041061         1997
# 499   877212         1969
# 500  1136869         1927
# 501   109380         1873
# 502  1555280         1952
#
# [503 rows x 8 columns]

# %%
tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0].Symbol
tickers
# Out:
# 0       MMM
# 1       AOS
# 2       ABT
# 3      ABBV
# 4       ACN
#        ...
# 498     YUM
# 499    ZBRA
# 500     ZBH
# 501    ZION
# 502     ZTS
# Name: Symbol, Length: 503, dtype: object

# %%
pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[1]
# Out:
#                   Date  Added                                Removed  \
#                   Date Ticker                       Security  Ticker
# 0          May 4, 2023   AXON                Axon Enterprise     FRC
# 1       March 20, 2023   FICO                     Fair Isaac    LUMN
# 2       March 15, 2023     BG                  Bunge Limited    SBNY
# 3       March 15, 2023   PODD                        Insulet    SIVB
# 4      January 5, 2023    NaN                            NaN     VNO
# ..                 ...    ...                            ...     ...
# 319       June 9, 1999    WLP                      Wellpoint     HPH
# 320  December 11, 1998    FSR                        Firstar     LDW
# 321  December 11, 1998    CCL                 Carnival Corp.     GRN
# 322  December 11, 1998   CPWR                      Compuware     SUN
# 323      June 17, 1997    CCI  Countrywide Credit Industries     USL
#
#                                \
#                      Security
# 0         First Republic Bank
# 1          Lumen Technologies
# 2              Signature Bank
# 3         SVB Financial Group
# 4        Vornado Realty Trust
# ..                        ...
# 319  Harnischfeger Industries
# 320                     Amoco
# 321                General Re
# 322                SunAmerica
# 323                    USLife
#
#                                                 Reason
#                                                 Reason
# 0    The Federal Deposit Insurance Corporation (FDI...
# 1                     Market capitalization change.[5]
# 2    The FDIC placed Signature Bank into FDIC Recei...
# 3    The FDIC placed SVB's main subsidiary, Silicon...
# 4                     Market capitalization change.[8]
# ..                                                 ...
# 319           Harnischfeger filed for bankruptcy.[245]
# 320            British Petroleum purchased Amoco.[246]
# 321      Berkshire Hathaway purchased General Re.[246]
# 322                     AIG purchased SunAmerica.[246]
# 323                          AIG acquired USLife.[247]
#
# [324 rows x 6 columns]

# %%
tickers_chg = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[1]
tickers_chg
# Out:
#                   Date  Added                                Removed  \
#                   Date Ticker                       Security  Ticker
# 0          May 4, 2023   AXON                Axon Enterprise     FRC
# 1       March 20, 2023   FICO                     Fair Isaac    LUMN
# 2       March 15, 2023     BG                  Bunge Limited    SBNY
# 3       March 15, 2023   PODD                        Insulet    SIVB
# 4      January 5, 2023    NaN                            NaN     VNO
# ..                 ...    ...                            ...     ...
# 319       June 9, 1999    WLP                      Wellpoint     HPH
# 320  December 11, 1998    FSR                        Firstar     LDW
# 321  December 11, 1998    CCL                 Carnival Corp.     GRN
# 322  December 11, 1998   CPWR                      Compuware     SUN
# 323      June 17, 1997    CCI  Countrywide Credit Industries     USL
#
#                                \
#                      Security
# 0         First Republic Bank
# 1          Lumen Technologies
# 2              Signature Bank
# 3         SVB Financial Group
# 4        Vornado Realty Trust
# ..                        ...
# 319  Harnischfeger Industries
# 320                     Amoco
# 321                General Re
# 322                SunAmerica
# 323                    USLife
#
#                                                 Reason
#                                                 Reason
# 0    The Federal Deposit Insurance Corporation (FDI...
# 1                     Market capitalization change.[5]
# 2    The FDIC placed Signature Bank into FDIC Recei...
# 3    The FDIC placed SVB's main subsidiary, Silicon...
# 4                     Market capitalization change.[8]
# ..                                                 ...
# 319           Harnischfeger filed for bankruptcy.[245]
# 320            British Petroleum purchased Amoco.[246]
# 321      Berkshire Hathaway purchased General Re.[246]
# 322                     AIG purchased SunAmerica.[246]
# 323                          AIG acquired USLife.[247]
#
# [324 rows x 6 columns]

# %%
pd.to_datetime(tickers_chg.Date.Date)
# Out:
# 0     2023-05-04
# 1     2023-03-20
# 2     2023-03-15
# 3     2023-03-15
# 4     2023-01-05
#          ...
# 319   1999-06-09
# 320   1998-12-11
# 321   1998-12-11
# 322   1998-12-11
# 323   1997-06-17
# Name: Date, Length: 324, dtype: datetime64[ns]

# %%
tickers_chg[pd.to_datetime(tickers_chg.Date.Date) >= '2019-01-01']
# Out:
#                  Date  Added                      Removed  \
#                  Date Ticker             Security  Ticker
# 0         May 4, 2023   AXON      Axon Enterprise     FRC
# 1      March 20, 2023   FICO           Fair Isaac    LUMN
# 2      March 15, 2023     BG        Bunge Limited    SBNY
# 3      March 15, 2023   PODD              Insulet    SIVB
# 4     January 5, 2023    NaN                  NaN     VNO
# ..                ...    ...                  ...     ...
# 82      April 2, 2019    DOW             Dow Inc.     BHF
# 83  February 27, 2019    WAB               Wabtec      GT
# 84  February 15, 2019    ATO         Atmos Energy     NFX
# 85   January 18, 2019    TFX             Teleflex     PCG
# 86    January 2, 2019    FRC  First Republic Bank     SCG
#
#                                         \
#                               Security
# 0                  First Republic Bank
# 1                   Lumen Technologies
# 2                       Signature Bank
# 3                  SVB Financial Group
# 4                 Vornado Realty Trust
# ..                                 ...
# 82               Brighthouse Financial
# 83  The Goodyear Tire & Rubber Company
# 84                Newfield Exploration
# 85      Pacific Gas & Electric Company
# 86                               SCANA
#
#                                                Reason
#                                                Reason
# 0   The Federal Deposit Insurance Corporation (FDI...
# 1                    Market capitalization change.[5]
# 2   The FDIC placed Signature Bank into FDIC Recei...
# 3   The FDIC placed SVB's main subsidiary, Silicon...
# 4                    Market capitalization change.[8]
# ..                                                ...
# 82                         DOW spun off from DWDP[59]
# 83        WAB acquired GE transportation business[60]
# 84                               ECA acquired NFX[61]
# 85                       PCG filed for bankruptcy[62]
# 86     Dominion Energy acquired SCANA Corporation[63]
#
# [87 rows x 6 columns]

# %%
added = tickers_chg[pd.to_datetime(tickers_chg.Date.Date) >= '2019-01-01'].Added
removed = tickers_chg[pd.to_datetime(tickers_chg.Date.Date) >= '2019-01-01'].Removed
# Out:
# (   Ticker             Security
#  0    AXON      Axon Enterprise
#  1    FICO           Fair Isaac
#  2      BG        Bunge Limited
#  3    PODD              Insulet
#  4     NaN                  NaN
#  ..    ...                  ...
#  82    DOW             Dow Inc.
#  83    WAB               Wabtec
#  84    ATO         Atmos Energy
#  85    TFX             Teleflex
#  86    FRC  First Republic Bank
#
#  [87 rows x 2 columns],
#     Ticker                            Security
#  0     FRC                 First Republic Bank
#  1    LUMN                  Lumen Technologies
#  2    SBNY                      Signature Bank
#  3    SIVB                 SVB Financial Group
#  4     VNO                Vornado Realty Trust
#  ..    ...                                 ...
#  82    BHF               Brighthouse Financial
#  83     GT  The Goodyear Tire & Rubber Company
#  84    NFX                Newfield Exploration
#  85    PCG      Pacific Gas & Electric Company
#  86    SCG                               SCANA
#
#  [87 rows x 2 columns])

# %%
tickers = tickers[~(tickers.isin(added.Ticker))]

# %%
tickers = tickers.append(removed.Ticker)
# Out:
# C:\Users\SHADOW\AppData\Local\Temp\ipykernel_11784\538431240.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tickers = tickers.append(removed.Ticker)
# 0      MMM
# 1      AOS
# 2      ABT
# 3     ABBV
# 4      ACN
#       ...
# 82     BHF
# 83      GT
# 84     NFX
# 85     PCG
# 86     SCG
# Length: 510, dtype: object

# %%
tickers.dropna(inplace=True)

# %%
tickers.drop_duplicates(inplace=True)

# %%
tickers = tickers.reset_index(drop=True)

# %%
tickers
# Out:
# 0       MMM
# 1       AOS
# 2       ABT
# 3      ABBV
# 4       ACN
#        ...
# 505     BHF
# 506      GT
# 507     NFX
# 508     PCG
# 509     SCG
# Length: 510, dtype: object
